# %%
#TITULO LABORATORIO 2
#FECHA 22/05/026
#AUTOR HUGO MARTÍNEZ VALLEJO

# %%
pip install panda
# Out:
# Requirement already satisfied: panda in C:\anaconda3\envs\Laboratorio\Lib\site-packages (0.3.1)
# Requirement already satisfied: setuptools in C:\anaconda3\envs\Laboratorio\Lib\site-packages (from panda) (82.0.1)
# Requirement already satisfied: requests in C:\anaconda3\envs\Laboratorio\Lib\site-packages (from panda) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\anaconda3\envs\Laboratorio\Lib\site-packages (from requests->panda) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\anaconda3\envs\Laboratorio\Lib\site-packages (from requests->panda) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\anaconda3\envs\Laboratorio\Lib\site-packages (from requests->panda) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\anaconda3\envs\Laboratorio\Lib\site-packages (from requests->panda) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Conjunto de datos base para la generaci´´on del Big Data
datos= {
"usuario": ["ana", "pepe", "Luis", "rosita", "carolina", "paco"],
"edad": [14,22,35,40,62,70],
"compras_realizadas": [5,10,1,2,15,3],
"activo": [True, True, False, True, False]
"fecha_registro":["2026-01-10", "2026-05-21", "2026-02-10", "2026-03-11", "2026-04-15","2026-07-25",]
}
